# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/home/app/data/Epileptic Seizure Recognition.csv')
data=data[data.columns[1:]]
data.loc[data['y']!=1,'y']=0

# %%
data.describe()
# Out:
#                  X1            X2            X3            X4            X5  \
# count  11500.000000  11500.000000  11500.000000  11500.000000  11500.000000
# mean     -11.581391    -10.911565    -10.187130     -9.143043     -8.009739
# std      165.626284    166.059609    163.524317    161.269041    160.998007
# min    -1839.000000  -1838.000000  -1835.000000  -1845.000000  -1791.000000
# 25%      -54.000000    -55.000000    -54.000000    -54.000000    -54.000000
# 50%       -8.000000     -8.000000     -7.000000     -8.000000     -8.000000
# 75%       34.000000     35.000000     36.000000     36.000000     35.000000
# max     1726.000000   1713.000000   1697.000000   1612.000000   1518.000000
#
#                  X6            X7           X8           X9           X10  \
# count  11500.000000  11500.000000  11500.00000  11500.00000  11500.000000
# mean      -7.003478     -6.502087     -6.68713     -6.55800     -6.168435
# ...

# %%
data.head()
# Out:
#     X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X170  X171  X172  \
# 0  135  190  229  223  192  125   55   -9  -33  -38  ...   -17   -15   -31
# 1  386  382  356  331  320  315  307  272  244  232  ...   164   150   146
# 2  -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  ...    57    64    48
# 3 -105 -101  -96  -92  -89  -95 -102 -100  -87  -79  ...   -82   -81   -80
# 4   -9  -65  -98 -102  -78  -48  -16    0  -21  -59  ...     4     2   -12
#
#    X173  X174  X175  X176  X177  X178  y
# 0   -77  -103  -127  -116   -83   -51  0
# 1   152   157   156   154   143   129  1
# 2    19   -12   -30   -35   -35   -36  0
# 3   -77   -85   -77   -72   -69   -65  0
# 4   -32   -41   -65   -83   -89   -73  0
#
# [5 rows x 179 columns]

# %% [markdown]
# # EDA

# %%
data.describe()
# Out:
#                  X1            X2            X3            X4            X5  \
# count  11500.000000  11500.000000  11500.000000  11500.000000  11500.000000
# mean     -11.581391    -10.911565    -10.187130     -9.143043     -8.009739
# std      165.626284    166.059609    163.524317    161.269041    160.998007
# min    -1839.000000  -1838.000000  -1835.000000  -1845.000000  -1791.000000
# 25%      -54.000000    -55.000000    -54.000000    -54.000000    -54.000000
# 50%       -8.000000     -8.000000     -7.000000     -8.000000     -8.000000
# 75%       34.000000     35.000000     36.000000     36.000000     35.000000
# max     1726.000000   1713.000000   1697.000000   1612.000000   1518.000000
#
#                  X6            X7           X8           X9           X10  \
# count  11500.000000  11500.000000  11500.00000  11500.00000  11500.000000
# mean      -7.003478     -6.502087     -6.68713     -6.55800     -6.168435
# ...

# %%
# check nan
data.isna().any().any()
# Out:
# False

# %% [markdown]
# Нет пропущенных значений

# %%
import seaborn as sns
ax = sns.countplot(x=data['y'],label="Count")
non_seizure, seizure = data['y'].value_counts()
print('Количество значений без приступа:', non_seizure)
print('Количество значений с приступом:', seizure)
# Out:
# Количество значений без приступа: 9200
# Количество значений с приступом: 2300

# %%
print('Totall Mean VALUE for Epiletic: {}'.format((data[data['y'] == 1].describe().mean()).mean()))
print('Totall Std VALUE for Epiletic: {}'.format((data[data['y'] == 1].describe().std()).std()))
# Out:
# Totall Mean VALUE for Epiletic: 290.129360958884
# Totall Std VALUE for Epiletic: 53.56315864740058

# %%
print('Totall Mean VALUE for NON Epiletic: {}'.format((data[data['y'] == 0].describe().mean()).mean()))
print('Totall Std VALUE for NON Epiletic: {}'.format((data[data['y'] == 0].describe().std()).std()))
# Out:
# Totall Mean VALUE for NON Epiletic: 1260.098927262616
# Totall Std VALUE for NON Epiletic: 15.561044289100993

# %%
#lists of arrays containing all data without y column
not_epileptic = [data[data['y']==0].iloc[:, range(0, len(data.columns)-1)].values]
epileptic = [data[data['y']==1].iloc[:, range(0, len(data.columns)-1)].values]

#We will create and calculate 2d indicators in order plot data in 2 dimensions;

def indic(data):
    """Indicators can be different. In our case we use just min and max values
    Additionally, it can be mean and std or another combination of indicators"""
    max = np.max(data, axis=1)
    min = np.min(data, axis=1)
    return max, min

x1,y1 = indic(not_epileptic)
x2,y2 = indic(epileptic)

fig = plt.figure(figsize=(14,6))
ax1 = fig.add_subplot(111)

ax1.scatter(x1, y1, s=10, c='b', label='Not Epiliptic')
ax1.scatter(x2, y2, s=10, c='r', label='Epileptic')
plt.legend(loc='lower left');
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, RobustScaler, LabelEncoder, OneHotEncoder, MinMaxScaler
from sklearn.pipeline import Pipeline, make_pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.feature_selection import SelectKBest, chi2, f_classif
from sklearn.linear_model import LogisticRegression
from sklearn.compose import make_column_selector as selector
from sklearn.utils import shuffle

from sklearn.metrics import classification_report, confusion_matrix, f1_score, make_scorer


data = shuffle(data)

y=data['y'].copy()
X=data.drop(columns=['y'])
X['min'],X['max']=indic(X.values)
#X=data.values[:,:-1]
#y=data.values[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    stratify=y, 
                                                    test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, VotingClassifier,GradientBoostingClassifier
from sklearn.svm import SVC



clf1 = LogisticRegression(max_iter=50, random_state=7575)
clf2 = RandomForestClassifier(n_estimators=50, random_state = 7575)
clf3 = GradientBoostingClassifier(random_state = 7575)
clf4=  SVC(gamma='auto')

blending_classifier = VotingClassifier(
    estimators=[("random_forest", clf2), 
                ("svm", clf4)] 
)
blending_classifier
# Out:
# VotingClassifier(estimators=[('random_forest',
#                               RandomForestClassifier(n_estimators=50,
#                                                      random_state=7575)),
#                              ('svm', SVC(gamma='auto'))])

# %%
numerical_transformer = Pipeline(steps=[("scaler", StandardScaler()),
                                        ])#("fs", SelectKBest(score_func=f_classif, k="all")), 
data_transformer = ColumnTransformer(transformers=[
    ("numerical", numerical_transformer,X.columns), # make_column_selector
])
preprocessor = Pipeline(steps=[("data_transformer", data_transformer)])

# %%
classifier_pipline = Pipeline(
    steps=[("preprocessor", preprocessor), 
           ("classifier",  blending_classifier)])

classifier_pipline
# Out:
# Pipeline(steps=[('preprocessor',
#                  Pipeline(steps=[('data_transformer',
#                                   ColumnTransformer(transformers=[('numerical',
#                                                                    Pipeline(steps=[('scaler',
#                                                                                     StandardScaler())]),
#                                                                    Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10',
#        ...
#        'X171', 'X172', 'X173', 'X174', 'X175', 'X176', 'X177', 'X178', 'min',
#        'max'],
#       dtype='object', length=180))]))])),
#                 ('classifier',
#                  VotingClassifier(estimators=[('random_forest',
#                                                RandomForestClassifier(n_estimators=50,
#                                                                       random_state=7575)),
# ...

# %%
classifier_pipline.fit(X_train, y_train)

preds = classifier_pipline.predict(X_test)

print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1840
#            1       0.96      0.89      0.92       460
#
#     accuracy                           0.97      2300
#    macro avg       0.97      0.94      0.95      2300
# weighted avg       0.97      0.97      0.97      2300

# %%
classifier_pipline.score(X_test,y_test)
# Out:
# 0.9708695652173913

# %%
classifier_pipline = Pipeline(
    steps=[("preprocessor", preprocessor), 
           ("classifier",  clf2)])

classifier_pipline
# Out:
# Pipeline(steps=[('preprocessor',
#                  Pipeline(steps=[('data_transformer',
#                                   ColumnTransformer(transformers=[('numerical',
#                                                                    Pipeline(steps=[('scaler',
#                                                                                     StandardScaler())]),
#                                                                    Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10',
#        ...
#        'X171', 'X172', 'X173', 'X174', 'X175', 'X176', 'X177', 'X178', 'min',
#        'max'],
#       dtype='object', length=180))]))])),
#                 ('classifier',
#                  RandomForestClassifier(n_estimators=50, random_state=7575))])

# %%
classifier_pipline.fit(X_train, y_train)

preds = classifier_pipline.predict(X_test)

print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1840
#            1       0.94      0.93      0.94       460
#
#     accuracy                           0.98      2300
#    macro avg       0.96      0.96      0.96      2300
# weighted avg       0.98      0.98      0.98      2300

# %%
classifier_pipline.score(X_test,y_test)
# Out:
# 0.9752173913043478

# %%
confusion_matrix(y_test,preds)
# Out:
# array([[1815,   25],
#        [  41,  419]])

# %%
confusion_matrix(y_test,preds)
# Out:
# array([[1821,   19],
#        [  40,  420]])

# %%
data.values[:,-1]
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
# Your code here.
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.ensemble import StackingClassifier
import xgboost

# %%
# получим список эстиматоров
estimators = [
    ("Random_Forest", RandomForestClassifier()),
    ("SVM", LinearSVC()),
    ("Xgboost", xgboost.XGBClassifier()),
]

# построим классификатор используя стекинг и наш список классификаторов
stacking_classifier = StackingClassifier(
    estimators=estimators, final_estimator=LogisticRegression(n_jobs=-1), n_jobs=-1
)

classifier_pipline = Pipeline(
    steps=[("preprocessor", preprocessor),
           ("classifier", stacking_classifier)]
)

classifier_pipline
# Out:
# Pipeline(steps=[('preprocessor',
#                  Pipeline(steps=[('data_transformer',
#                                   ColumnTransformer(transformers=[('numerical',
#                                                                    Pipeline(steps=[('scaler',
#                                                                                     StandardScaler()),
#                                                                                    ('fs',
#                                                                                     SelectKBest(k='all'))]),
#                                                                    Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10',
#        ...
#        'X171', 'X172', 'X173', 'X174', 'X175', 'X176', 'X177', 'X178', 'min',
#        'max'],
#       dtype='object', length=180))]))]))...
#                                                                interaction_constraints=None,
# ...

# %%
classifier_pipline.fit(X_train, y_train)

preds = classifier_pipline.predict(X_test)

print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1840
#            1       0.94      0.91      0.93       460
#
#     accuracy                           0.97      2300
#    macro avg       0.96      0.95      0.95      2300
# weighted avg       0.97      0.97      0.97      2300

# %%
# SVM Classifier
classifier_pipline.score(X_test,y_test)
# Out:
# 0.9791304347826087

# %%
# SVM Classifier + RF
classifier_pipline.score(X_test,y_test)
# Out:
# 0.9726086956521739

# %%
classifier_pipline.score(X_test,y_test)
# Out:
# 0.9773913043478261

# %%
confusion_matrix(y_test,preds)
# Out:
# array([[1818,   22],
#        [  30,  430]])
